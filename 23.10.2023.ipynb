# %%
print("Hello")
# Out:
# Hello

# %%
2+3
# Out:
# 5

# %%
from platform import python_version
print(python_version())
# Out:
# 3.10.8

# %%
# Single Line Comment
print("Hello")
# Out:
# Hello

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
name=input("Enter Your Name:")
print(name)
# Out:
# Rana Corporation

# %%
print(name.split())
# Out:
# ['Rana', 'Corporation']

# %%
a=input("Enter A:")
b=input("Enter B:")
print(a+b)
# Out:
# 151

# %%
a=int(input("Enter A:"))
b=int(input("Enter B"))
print(a+b)
# Out:
# 35

# %%
a=20
b=9
print(a/b)
print(a//b)
# Out:
# 2.2222222222222223
# 2

# %%
a=2
b=3
print(a*b)
print(a**b)
# Out:
# 6
# 8

# %%
statement="  Hello  "
statement.strip()
# Out:
# 'Hello'

# %%
string="{2} {1} {0}".format("Hello","World","Me")
print(string)
# Out:
# Me World Hello

# %%
string="Rana"
print(string[::-1])
# Out:
# anaR

# %% [markdown]
# ### Python Lists

# %%
mylist=["Red",23,False,3.4]
print(mylist)
print(type(mylist))
# Out:
# ['Red', 23, False, 3.4]
# <class 'list'>

# %%
print(mylist[0])
# Out:
# Red

# %% [markdown]
# ### Python Tuples

# %%
mytuple=("Hello",7,True,"Rana")
print(mytuple)
print(type(mytuple))
# Out:
# ('Hello', 7, True, 'Rana')
# <class 'tuple'>

# %%
print(mytuple[2])
# Out:
# True

# %%
print(mytuple[1:3])
# Out:
# (7, True)

# %%
mytuple2=("Gandhi","Patel")
mytuple3=mytuple+mytuple2
print(mytuple3)
# Out:
# ('Hello', 7, True, 'Rana', 'Gandhi', 'Patel')

# %%
# del is keyword used fro deleting the items
# immutable
del mytuple3[2]
print(mytuple3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Dishang\Downloads\Code-Unnati\PythonBook.ipynb Cell 23 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Dishang/Downloads/Code-Unnati/PythonBook.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> # del is keyword used fro deleting the items
#       <a href='vscode-notebook-cell:/c%3A/Users/Dishang/Downloads/Code-Unnati/PythonBook.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> # immutable
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dishang/Downloads/Code-Unnati/PythonBook.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> del mytuple3[2]
#       <a href='vscode-notebook-cell:/c%3A/Users/Dishang/Downloads/Code-Unnati/PythonBook.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> print(mytuple3)
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple3[2]=False
print(mytuple3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Dishang\Downloads\Code-Unnati\PythonBook.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dishang/Downloads/Code-Unnati/PythonBook.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> mytuple3[2]=False
#       <a href='vscode-notebook-cell:/c%3A/Users/Dishang/Downloads/Code-Unnati/PythonBook.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> print(mytuple3)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### Tuples Method

# %%
numbers=(1,2,3,4,9,1,3,9,0,1,2,8,2,1)
print(numbers.count(1))
# Out:
# 4

# %%
print(numbers.index(9))
# Out:
# 4

# %% [markdown]
# ### Python Dictionary

# %%
mydict={"Name":"John","Age":34,"Gender":"Male"}
print(mydict)
print(type(mydict))
# Out:
# {'Name': 'John', 'Age': 34, 'Gender': 'Male'}
# <class 'dict'>

# %%
print(mydict["Name"])
# Out:
# John

# %% [markdown]
# #### Dictionary Method

# %%
print(mydict.keys())
# Out:
# dict_keys(['Name', 'Age', 'Gender'])

# %%
print(mydict.values())
# Out:
# dict_values(['John', 34, 'Male'])

# %%
print(mydict.items())
# Out:
# dict_items([('Name', 'John'), ('Age', 34), ('Gender', 'Male')])

# %%
mydict.update({"Age":30})
print(mydict)
# Out:
# {'Name': 'John', 'Age': 30, 'Gender': 'Male'}

# %%
mydict["Weight"]=62
print(mydict)
# Out:
# {'Name': 'John', 'Age': 30, 'Gender': 'Male', 'Weight': 62}

# %%
mydict.pop("Gender")
print(mydict)
# Out:
# {'Name': 'John', 'Age': 30, 'Weight': 62}

# %% [markdown]
# ### Python Sets

# %%
subject1={"Hindi","English","Gujarati","Maths","Sanskrit"}
print(subject1)
print(type(subject1))
# Out:
# {'Gujarati', 'Hindi', 'English', 'Maths', 'Sanskrit'}
# <class 'set'>

# %%
subject2={"BA","Eco","State","English"}
# pipe symbol used to make union of two sets
subject1|subject2
# Out:
# {'BA', 'Eco', 'English', 'Gujarati', 'Hindi', 'Maths', 'Sanskrit', 'State'}

# %%
# union method to make union of two sets
subject1.union(subject2)
# Out:
# {'BA', 'Eco', 'English', 'Gujarati', 'Hindi', 'Maths', 'Sanskrit', 'State'}

# %%
subject1.intersection(subject2)
# Out:
# {'English'}

# %% [markdown]
# ### Python Built in Function

# %%
fruits=["Banana","Orange","Kiwi","Apple"]
len(fruits)
# Out:
# 4

# %%
name="Rana Corporation"
len(name)
# Out:
# 16

# %%
sorted(fruits)
# Out:
# ['Apple', 'Banana', 'Kiwi', 'Orange']

# %%
numbers=[10,3,24,78,100,2,4,67,200]
max(numbers)
# Out:
# 200

# %%
sum(numbers)
# Out:
# 488

# %% [markdown]
# #### List Built in Function

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# #### Set Built in Function

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# #### Tuple Built in Function

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %% [markdown]
# ### Type Casting

# %%
n=10
print(n)
print(type(n))

print(float(n))
print(type(float(n)))
# Out:
# 10
# <class 'int'>
# 10.0
# <class 'float'>

# %%
print(str(n))
print(type(str(n)))
# Out:
# 10
# <class 'str'>

# %%
mylist=["Apple","Banana","Cherry"]
print(mylist)
print(type(mylist))

print(tuple(mylist))
print(type(tuple(mylist)))
# Out:
# ['Apple', 'Banana', 'Cherry']
# <class 'list'>
# ('Apple', 'Banana', 'Cherry')
# <class 'tuple'>
